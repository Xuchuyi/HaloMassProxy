# %%
import os
import copy
import pickle
import warnings
import pandas as pd
import numpy as np
import numpy.ma as ma
from scipy.interpolate import interp1d
from scipy.optimize import curve_fit
from scipy.stats import bootstrap

import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib import colors
import palettable
import deepdish as dd

from astropy.utils.console import ProgressBar
from astropy.table import QTable,hstack
plt.rc('text', usetex=True)
rcParams.update({'axes.linewidth': 1.5})
rcParams.update({'xtick.direction': 'in'})
rcParams.update({'ytick.direction': 'in'})
rcParams.update({'xtick.minor.visible': 'True'})
rcParams.update({'ytick.minor.visible': 'True'})
rcParams.update({'xtick.major.pad': '7.0'})
rcParams.update({'xtick.major.size': '8.0'})
rcParams.update({'xtick.major.width': '1.5'})
rcParams.update({'xtick.minor.pad': '7.0'})
rcParams.update({'xtick.minor.size': '4.0'})
rcParams.update({'xtick.minor.width': '1.5'})
rcParams.update({'ytick.major.pad': '7.0'})
rcParams.update({'ytick.major.size': '8.0'})
rcParams.update({'ytick.major.width': '1.5'})
rcParams.update({'ytick.minor.pad': '7.0'})
rcParams.update({'ytick.minor.size': '4.0'})
rcParams.update({'ytick.minor.width': '1.5'})
rcParams.update({'axes.titlepad': '10.0'})
rcParams.update({'font.size': 30})

# %%
data_dir="/Users/xushuo/work/Submit/Simulation/data/"
fig_dir="/Users/xushuo/work/Papers/Simulation/Figure/"

# %%
tab0=dd.io.load(data_dir+'galaxies_tng300_072_correct.hdf5','/physical_mass')
tab1=dd.io.load(data_dir+'galaxies_tng300_072_correct.hdf5','/reff_mass')

# %%
tab1
# Out:
# <QTable length=8139>
# gal_num proj catsh_primary ... aper_10reff_ins_force aper_10reff_exs_force
#  int64  str2      bool     ...        float64               float64
# ------- ---- ------------- ... --------------------- ---------------------
#       0   xy          True ...     549864876039.7445    1763320556703.1975
#       0   yz          True ...     556775179977.3945    1883528386452.8787
#       0   xz          True ...     558650090107.5175    2043827221258.3325
#       1   xy          True ...     354373708374.9373    2303225660959.2065
#       1   yz          True ...     364655458315.6506     2317656468138.388
#       1   xz          True ...      364305700717.161     2284300544112.318
#     ...  ...           ... ...                   ...                   ...
#    2710   xz          True ...     89159134367.50302    62179227908.070595
#    2711   xy          True ...    67810042069.584946     86748398284.49792
#    2711   yz          True ...     68028454952.22033     88471112388.29533
#    2711   xz          True ...     67876477349.03942     88123548452.79669
#    2712   xy          True ...     65070246222.99593     90171211548.20364
#    2712   yz          True ...    65055160718.400635     89735844607.86465
#    2712   xz          True ...     64897003855.40297      89793180295.6598

# %%
sma_list=np.asarray([30,50,75,100,150])
sma_list0=np.asarray([1,2,3,4,5,8,10])

# %%
def mpeakfind(tab,bin_num=30):
    numb,bins=np.histogram(tab,bins=bin_num)
    max_value=max(numb)
    max_index=list(numb).index(max_value)
    mpeak=bins[max_index]
    return mpeak

# %%
def mockdata(tab,sigma_aper=0.1,sigma_out=0.15):
    err=np.random.lognormal(sigma=sigma_aper,size=len(tab))
    mock_gal_num=tab[tab.colnames[0]]
    mock_proj=tab[tab.colnames[1]]
    mock_catsh_primary=tab[tab.colnames[2]]
    mock_mass_halo=tab[tab.colnames[3]]
    mock_mass_stellar_gal=tab[tab.colnames[4]]*err
    mock_mass_stellar_ins=tab[tab.colnames[5]]*err
    mock_mass_stellar_exs=tab[tab.colnames[6]]*err
    for map_type in ('ins','exs','gal'):
        for i in sma_list:
            meta=tab['aper_'+str(i)+'_'+
                 map_type]*err
            exec('global mock_aper_'+str(i)+'_'+map_type
                 +';mock_aper_'+str(i)+'_'+map_type+'=meta')
        for i in sma_list[:-2:]:
            meta=(np.asarray(tab['aper_100_'+map_type
                 ])-np.asarray(tab['aper_'+str(i)+'_'+map_type]))*err*1.5
            exec('global mock_out_'+str(i)+'_100_'+map_type+
                 '0;mock_out_'+str(i)+'_100_'+map_type+'0=meta')
            exec('global mock_out_'+str(i)+'_100_'+map_type+
                 ';mock_out_'+str(i)+'_100_'+map_type+'=QTable([mock_out_'+str(i)+'_100_'+
                 map_type+'0,],names=("out_'+str(i)+'_100_'+map_type+'",))')
    table=hstack([mock_gal_num,mock_proj,mock_catsh_primary,mock_mass_halo,mock_mass_stellar_gal,mock_mass_stellar_ins,mock_mass_stellar_exs,
                  #mock_aper_10_ins,mock_aper_10_exs,mock_aper_10_gal,mock_aper_10_ins_force,mock_aper_10_exs_force,
                  mock_aper_30_ins,mock_aper_30_exs,mock_aper_30_gal,
                  mock_aper_50_ins,mock_aper_50_exs,mock_aper_50_gal,
                  mock_aper_75_ins,mock_aper_75_exs,mock_aper_75_gal,
                  mock_aper_100_ins,mock_aper_100_exs,mock_aper_100_gal,
                  mock_aper_150_ins,mock_aper_150_exs,mock_aper_150_gal,
                  #mock_out_10_100_ins,mock_out_10_100_exs,mock_out_10_100_gal,mock_out_10_100_ins_force,mock_out_10_100_exs_force,
                  mock_out_30_100_ins,mock_out_30_100_exs,mock_out_30_100_gal,
                  mock_out_50_100_ins,mock_out_50_100_exs,mock_out_50_100_gal,
                  mock_out_75_100_ins,mock_out_75_100_exs,mock_out_75_100_gal])
    return table

# %%
def mockreffdata(tab,sigma_aper=0.1,sigma_out=0.15):
    err=np.random.lognormal(sigma=sigma_aper,size=len(tab))
    mock_gal_num=tab[tab.colnames[0]]
    mock_proj=tab[tab.colnames[1]]
    mock_catsh_primary=tab[tab.colnames[2]]
    mock_mass_halo=tab[tab.colnames[3]]
    mock_mass_stellar_gal=tab[tab.colnames[4]]*err
    mock_mass_stellar_ins=tab[tab.colnames[5]]*err
    mock_mass_stellar_exs=tab[tab.colnames[6]]*err
    for map_type in ('ins','exs','gal','ins_force','exs_force'):
        for i in sma_list0:
            meta=tab['aper_'+str(i)+'reff_'+
                 map_type]*err
            exec('global mock_aper_'+str(i)+'reff_'+map_type
                 +';mock_aper_'+str(i)+'reff_'+map_type+'=meta')
        for i in sma_list0[:-2:]:
            meta=(np.asarray(tab['aper_8reff_'+map_type
                 ])-np.asarray(tab['aper_'+str(i)+'reff_'+map_type]))*err*1.5
            exec('global mock_out_'+str(i)+'_8reff_'+map_type+
                 '0;mock_out_'+str(i)+'_8reff_'+map_type+'0=meta')
            exec('global mock_out_'+str(i)+'_8reff_'+map_type+
                 ';mock_out_'+str(i)+'_8reff_'+map_type+'=QTable([mock_out_'+str(i)+'_8reff_'+
                 map_type+'0,],names=("out_'+str(i)+'_8reff_'+map_type+'",))')
    table=hstack([mock_gal_num,mock_proj,mock_mass_halo,mock_mass_stellar_gal,mock_mass_stellar_ins,mock_mass_stellar_exs,
                  mock_aper_1reff_ins,mock_aper_1reff_exs,mock_aper_1reff_gal,mock_aper_1reff_ins_force,mock_aper_1reff_exs_force,
                  mock_aper_2reff_ins,mock_aper_2reff_exs,mock_aper_2reff_gal,mock_aper_2reff_ins_force,mock_aper_2reff_exs_force,
                  mock_aper_3reff_ins,mock_aper_3reff_exs,mock_aper_3reff_gal,mock_aper_3reff_ins_force,mock_aper_3reff_exs_force,
                  mock_aper_4reff_ins,mock_aper_4reff_exs,mock_aper_4reff_gal,mock_aper_4reff_ins_force,mock_aper_4reff_exs_force,
                  mock_aper_5reff_ins,mock_aper_5reff_exs,mock_aper_5reff_gal,mock_aper_5reff_ins_force,mock_aper_5reff_exs_force,
                  mock_aper_8reff_ins,mock_aper_8reff_exs,mock_aper_8reff_gal,mock_aper_8reff_ins_force,mock_aper_8reff_exs_force,
                  mock_aper_10reff_ins,mock_aper_10reff_exs,mock_aper_10reff_gal,mock_aper_10reff_ins_force,mock_aper_10reff_exs_force,
                  mock_out_1_8reff_ins,mock_out_1_8reff_exs,mock_out_1_8reff_gal,mock_out_1_8reff_ins_force,mock_out_1_8reff_exs_force,
                  mock_out_2_8reff_ins,mock_out_2_8reff_exs,mock_out_2_8reff_gal,mock_out_2_8reff_ins_force,mock_out_2_8reff_exs_force,
                  mock_out_3_8reff_ins,mock_out_3_8reff_exs,mock_out_3_8reff_gal,mock_out_3_8reff_ins_force,mock_out_3_8reff_exs_force,
                  mock_out_4_8reff_ins,mock_out_4_8reff_exs,mock_out_4_8reff_gal,mock_out_4_8reff_ins_force,mock_out_4_8reff_exs_force,
                  mock_out_5_8reff_ins,mock_out_5_8reff_exs,mock_out_5_8reff_gal,mock_out_5_8reff_ins_force,mock_out_5_8reff_exs_force,])
    return table

# %%
def topNselect(data,name,number):
    data_meta=data.group_by(name)
    data0=data_meta[-number::]
    return data0
def medNselect(data,name,numb1,numb2):
    data_meta=data.group_by(name)
    if numb1!=0:
        data0=data_meta[-numb2:-numb1:]
    else:
        data0=data_meta[-numb2::]
    return data0
def mocktopNscatter(data,name,number):
    scatter=[]
    for i in range(1000):
        data_mock=mockdata(data)
        topN=topNselect(data_mock,name,number)
        scatter.append(np.std(np.log10(topN['mass_halo']),ddof=1))
    print(name)
    mean=np.mean(scatter)
    sca=np.std(scatter,ddof=1)
    return mean,sca
def mockmedNscatter(data,name,numb1,numb2):
    scatter=[]
    for i in range(1000):
        data_mock=mockdata(data)
        medN=medNselect(data_mock,name,numb1,numb2)
        scatter.append(np.std(np.log10(medN['mass_halo']),ddof=1))
    print(name)
    mean=np.mean(scatter)
    sca=np.std(scatter,ddof=1)
    return mean,sca
def mocktopNreffscatter(data,name,number):
    scatter=[]
    for i in range(1000):
        data_mock=mockreffdata(data)
        topN=topNselect(data_mock,name,number)
        scatter.append(np.std(np.log10(topN['mass_halo']),ddof=1))
    print(name)
    mean=np.mean(scatter)
    sca=np.std(scatter,ddof=1)
    return mean,sca
def mockmedNreffscatter(data,name,numb1,numb2):
    scatter=[]
    for i in range(1000):
        data_mock=mockreffdata(data)
        medN=medNselect(data_mock,name,numb1,numb2)
        scatter.append(np.std(np.log10(medN['mass_halo']),ddof=1))
    print(name)
    mean=np.mean(scatter)
    sca=np.std(scatter,ddof=1)
    return mean,sca

# %%
numb_list1=np.asarray([50,100,200,500,1000,1500])
numb_list2=np.asarray([50,180,350,700,1200])

# %%
numb_list=numb_list1

# %%
numb_list=numb_list1
mask0=(tab0['catsh_primary']==True)&(tab0['proj']=='xy')&(tab0["mass_stellar_ins"]>1e10)&(tab0["mass_stellar_exs"]>10**10.5)
name_tab=[]
tab=tab0[mask0]
for i in range(len(numb_list)):
    exec('tng300_'+str(numb_list[i])+'_scatter_mean=[]')
    exec('tng300_'+str(numb_list[i])+'_scatter_err=[]')
for i in sma_list:
    for map_type in ('ins','exs','gal'):
        exec('name="aper_'+str(i)+'_'+map_type+'"')
        name_tab.append('aper_'+str(i)+'_'+map_type)
        mpeak=mpeakfind(np.log10(tab['aper_'+str(i)+'_'+map_type]))
        mask=(tab['aper_'+str(i)+'_'+map_type]>10**mpeak)
        for j in range(len(numb_list)):
            mean,err=mocktopNscatter(tab[mask],name,numb_list[j])
            exec('tng300_'+str(numb_list[j])+'_scatter_mean.append(mean)')
            exec('tng300_'+str(numb_list[j])+'_scatter_err.append(err)')
for i in sma_list[:-2:]:
    for map_type in ('ins','exs','gal'):
        exec('name="out_'+str(i)+'_100_'+map_type+'"')
        name_tab.append('out_'+str(i)+'_100_'+map_type)
        mpeak=mpeakfind(np.log10(tab['aper_100_'+map_type]-tab['aper_'+str(i)+'_'+map_type]))
        mask=(tab['aper_100_'+map_type]-tab['aper_'+str(i)+'_'+map_type]>10**mpeak)
        for j in range(len(numb_list)):
            mean,err=mocktopNscatter(tab[mask],name,numb_list[j])
            exec('tng300_'+str(numb_list[j])+'_scatter_mean.append(mean)')
            exec('tng300_'+str(numb_list[j])+'_scatter_err.append(err)')
for map_type in ('ins','exs','gal'):
    exec('name="mass_stellar_'+map_type+'"')
    name_tab.append('mass_stellar_'+map_type)
    mpeak=mpeakfind(np.log10(tab[name]))
    mask=(tab[name]>10**mpeak)
    for j in range(len(numb_list)):
        mean,err=mocktopNscatter(tab[mask],name,numb_list[j])
        exec('tng300_'+str(numb_list[j])+'_scatter_mean.append(mean)')
        exec('tng300_'+str(numb_list[j])+'_scatter_err.append(err)')
mask1=(tab1['catsh_primary']==True)&(tab1['proj']=='xy')&(tab1["mass_stellar_ins"]>1e10)&(tab1["mass_stellar_exs"]>10**10.5)
tab=tab1[mask1]
for i in sma_list0:
    for map_type in ('ins','exs','gal','ins_force','exs_force'):
        exec('name="aper_'+str(i)+'reff_'+map_type+'"')
        name_tab.append('aper_'+str(i)+'reff_'+map_type)
        mpeak=mpeakfind(np.log10(tab['aper_'+str(i)+'reff_'+map_type]))
        mask=(tab['aper_'+str(i)+'reff_'+map_type]>10**mpeak)
        for j in range(len(numb_list)):
            mean,err=mocktopNreffscatter(tab[mask],name,numb_list[j])
            exec('tng300_'+str(numb_list[j])+'_scatter_mean.append(mean)')
            exec('tng300_'+str(numb_list[j])+'_scatter_err.append(err)')
for i in sma_list0[:-2:]:
    for map_type in ('ins','exs','gal','ins_force','exs_force'):
        exec('name="out_'+str(i)+'_8reff_'+map_type+'"')
        name_tab.append('out_'+str(i)+'_8reff_'+map_type)
        mask0=(tab['aper_8reff_'+map_type]-tab['aper_'+str(i)+'reff_'+map_type])>0
        mpeak=mpeakfind(np.log10(tab[mask0]['aper_8reff_'+map_type]-tab[mask0]['aper_'+str(i)+'reff_'+map_type]))
        mask=(tab['aper_8reff_'+map_type]-tab['aper_'+str(i)+'reff_'+map_type]>10**mpeak)
        for j in range(len(numb_list)):
            mean,err=mocktopNreffscatter(tab[mask],name,numb_list[j])
            exec('tng300_'+str(numb_list[j])+'_scatter_mean.append(mean)')
            exec('tng300_'+str(numb_list[j])+'_scatter_err.append(err)')
# Out:
# aper_30_ins
# aper_30_ins
# aper_30_ins
# aper_30_ins
# aper_30_ins
# aper_30_ins
# aper_30_exs
# aper_30_exs
# aper_30_exs
# aper_30_exs
# aper_30_exs
# aper_30_exs
# aper_30_gal
# aper_30_gal
# aper_30_gal
# aper_30_gal
# aper_30_gal
# aper_30_gal
# aper_50_ins
# aper_50_ins
# aper_50_ins
# aper_50_ins
# aper_50_ins
# aper_50_ins
# aper_50_exs
# aper_50_exs
# aper_50_exs
# aper_50_exs
# aper_50_exs
# aper_50_exs
# aper_50_gal
# aper_50_gal
# aper_50_gal
# aper_50_gal
# aper_50_gal
# aper_50_gal
# aper_75_ins
# aper_75_ins
# aper_75_ins
# aper_75_ins
# aper_75_ins
# aper_75_ins
# aper_75_exs
# aper_75_exs
# aper_75_exs
# aper_75_exs
# aper_75_exs
# aper_75_exs
# aper_75_gal
# aper_75_gal
# aper_75_gal
# aper_75_gal
# aper_75_gal
# aper_75_gal
# aper_100_ins
# aper_100_ins
# aper_100_ins
# aper_100_ins
# aper_100_ins
# aper_100_ins
# aper_100_exs
# aper_100_exs
# aper_100_exs
# aper_100_exs
# aper_100_exs
# aper_100_exs
# aper_100_gal
# aper_100_gal
# aper_100_gal
# aper_100_gal
# aper_100_gal
# aper_100_gal
# aper_150_ins
# aper_150_ins
# aper_150_ins
# aper_150_ins
# aper_150_ins
# aper_150_ins
# aper_150_exs
# aper_150_exs
# aper_150_exs
# aper_150_exs
# aper_150_exs
# aper_150_exs
# aper_150_gal
# aper_150_gal
# aper_150_gal
# aper_150_gal
# aper_150_gal
# aper_150_gal
# out_30_100_ins
# out_30_100_ins
# out_30_100_ins
# out_30_100_ins
# out_30_100_ins
# out_30_100_ins
# out_30_100_exs
# out_30_100_exs
# out_30_100_exs
# out_30_100_exs
# out_30_100_exs
# out_30_100_exs
# out_30_100_gal
# out_30_100_gal
# out_30_100_gal
# out_30_100_gal
# out_30_100_gal
# out_30_100_gal
# out_50_100_ins
# out_50_100_ins
# out_50_100_ins
# out_50_100_ins
# out_50_100_ins
# out_50_100_ins
# out_50_100_exs
# out_50_100_exs
# out_50_100_exs
# out_50_100_exs
# out_50_100_exs
# out_50_100_exs
# out_50_100_gal
# out_50_100_gal
# out_50_100_gal
# out_50_100_gal
# out_50_100_gal
# out_50_100_gal
# out_75_100_ins
# out_75_100_ins
# out_75_100_ins
# out_75_100_ins
# out_75_100_ins
# out_75_100_ins
# out_75_100_exs
# out_75_100_exs
# out_75_100_exs
# out_75_100_exs
# out_75_100_exs
# out_75_100_exs
# out_75_100_gal
# out_75_100_gal
# out_75_100_gal
# out_75_100_gal
# out_75_100_gal
# out_75_100_gal
# mass_stellar_ins
# mass_stellar_ins
# mass_stellar_ins
# mass_stellar_ins
# mass_stellar_ins
# mass_stellar_ins
# mass_stellar_exs
# mass_stellar_exs
# mass_stellar_exs
# mass_stellar_exs
# mass_stellar_exs
# mass_stellar_exs
# mass_stellar_gal
# mass_stellar_gal
# mass_stellar_gal
# mass_stellar_gal
# mass_stellar_gal
# mass_stellar_gal
# aper_1reff_ins
# aper_1reff_ins
# aper_1reff_ins
# aper_1reff_ins
# aper_1reff_ins
# aper_1reff_ins
# aper_1reff_exs
# aper_1reff_exs
# aper_1reff_exs
# aper_1reff_exs
# aper_1reff_exs
# aper_1reff_exs
# aper_1reff_gal
# aper_1reff_gal
# aper_1reff_gal
# aper_1reff_gal
# aper_1reff_gal
# aper_1reff_gal
# aper_1reff_ins_force
# aper_1reff_ins_force
# aper_1reff_ins_force
# aper_1reff_ins_force
# aper_1reff_ins_force
# aper_1reff_ins_force
# aper_1reff_exs_force
# aper_1reff_exs_force
# aper_1reff_exs_force
# aper_1reff_exs_force
# aper_1reff_exs_force
# aper_1reff_exs_force
# aper_2reff_ins
# aper_2reff_ins
# aper_2reff_ins
# aper_2reff_ins
# aper_2reff_ins
# aper_2reff_ins
# aper_2reff_exs
# aper_2reff_exs
# aper_2reff_exs
# aper_2reff_exs
# aper_2reff_exs
# aper_2reff_exs
# aper_2reff_gal
# aper_2reff_gal
# aper_2reff_gal
# aper_2reff_gal
# aper_2reff_gal
# aper_2reff_gal
# aper_2reff_ins_force
# aper_2reff_ins_force
# aper_2reff_ins_force
# aper_2reff_ins_force
# aper_2reff_ins_force
# aper_2reff_ins_force
# aper_2reff_exs_force
# aper_2reff_exs_force
# aper_2reff_exs_force
# aper_2reff_exs_force
# aper_2reff_exs_force
# aper_2reff_exs_force
# aper_3reff_ins
# aper_3reff_ins
# aper_3reff_ins
# aper_3reff_ins
# aper_3reff_ins
# aper_3reff_ins
# aper_3reff_exs
# aper_3reff_exs
# aper_3reff_exs
# aper_3reff_exs
# aper_3reff_exs
# aper_3reff_exs
# aper_3reff_gal
# aper_3reff_gal
# aper_3reff_gal
# aper_3reff_gal
# aper_3reff_gal
# aper_3reff_gal
# aper_3reff_ins_force
# aper_3reff_ins_force
# aper_3reff_ins_force
# aper_3reff_ins_force
# aper_3reff_ins_force
# aper_3reff_ins_force
# aper_3reff_exs_force
# aper_3reff_exs_force
# aper_3reff_exs_force
# aper_3reff_exs_force
# aper_3reff_exs_force
# aper_3reff_exs_force
# aper_4reff_ins
# aper_4reff_ins
# aper_4reff_ins
# aper_4reff_ins
# aper_4reff_ins
# aper_4reff_ins
# aper_4reff_exs
# aper_4reff_exs
# aper_4reff_exs
# aper_4reff_exs
# aper_4reff_exs
# aper_4reff_exs
# aper_4reff_gal
# aper_4reff_gal
# aper_4reff_gal
# aper_4reff_gal
# aper_4reff_gal
# aper_4reff_gal
# aper_4reff_ins_force
# aper_4reff_ins_force
# aper_4reff_ins_force
# aper_4reff_ins_force
# aper_4reff_ins_force
# aper_4reff_ins_force
# aper_4reff_exs_force
# aper_4reff_exs_force
# aper_4reff_exs_force
# aper_4reff_exs_force
# aper_4reff_exs_force
# aper_4reff_exs_force
# aper_5reff_ins
# aper_5reff_ins
# aper_5reff_ins
# aper_5reff_ins
# aper_5reff_ins
# aper_5reff_ins
# aper_5reff_exs
# aper_5reff_exs
# aper_5reff_exs
# aper_5reff_exs
# aper_5reff_exs
# aper_5reff_exs
# aper_5reff_gal
# aper_5reff_gal
# aper_5reff_gal
# aper_5reff_gal
# aper_5reff_gal
# aper_5reff_gal
# aper_5reff_ins_force
# aper_5reff_ins_force
# aper_5reff_ins_force
# aper_5reff_ins_force
# aper_5reff_ins_force
# aper_5reff_ins_force
# aper_5reff_exs_force
# aper_5reff_exs_force
# aper_5reff_exs_force
# aper_5reff_exs_force
# aper_5reff_exs_force
# aper_5reff_exs_force
# aper_8reff_ins
# aper_8reff_ins
# aper_8reff_ins
# aper_8reff_ins
# aper_8reff_ins
# aper_8reff_ins
# aper_8reff_exs
# aper_8reff_exs
# aper_8reff_exs
# aper_8reff_exs
# aper_8reff_exs
# aper_8reff_exs
# aper_8reff_gal
# aper_8reff_gal
# aper_8reff_gal
# aper_8reff_gal
# aper_8reff_gal
# aper_8reff_gal
# aper_8reff_ins_force
# aper_8reff_ins_force
# aper_8reff_ins_force
# aper_8reff_ins_force
# aper_8reff_ins_force
# aper_8reff_ins_force
# aper_8reff_exs_force
# aper_8reff_exs_force
# aper_8reff_exs_force
# aper_8reff_exs_force
# aper_8reff_exs_force
# aper_8reff_exs_force
# aper_10reff_ins
# aper_10reff_ins
# aper_10reff_ins
# aper_10reff_ins
# aper_10reff_ins
# aper_10reff_ins
# aper_10reff_exs
# aper_10reff_exs
# aper_10reff_exs
# aper_10reff_exs
# aper_10reff_exs
# aper_10reff_exs
# aper_10reff_gal
# aper_10reff_gal
# aper_10reff_gal
# aper_10reff_gal
# aper_10reff_gal
# aper_10reff_gal
# aper_10reff_ins_force
# aper_10reff_ins_force
# aper_10reff_ins_force
# aper_10reff_ins_force
# aper_10reff_ins_force
# aper_10reff_ins_force
# aper_10reff_exs_force
# aper_10reff_exs_force
# aper_10reff_exs_force
# aper_10reff_exs_force
# aper_10reff_exs_force
# aper_10reff_exs_force
# out_1_8reff_ins
# out_1_8reff_ins
# out_1_8reff_ins
# out_1_8reff_ins
# out_1_8reff_ins
# out_1_8reff_ins
# out_1_8reff_exs
# out_1_8reff_exs
# out_1_8reff_exs
# out_1_8reff_exs
# out_1_8reff_exs
# out_1_8reff_exs
# out_1_8reff_gal
# out_1_8reff_gal
# out_1_8reff_gal
# out_1_8reff_gal
# out_1_8reff_gal
# out_1_8reff_gal
# out_1_8reff_ins_force
# out_1_8reff_ins_force
# out_1_8reff_ins_force
# out_1_8reff_ins_force
# out_1_8reff_ins_force
# out_1_8reff_ins_force
# out_1_8reff_exs_force
# out_1_8reff_exs_force
# out_1_8reff_exs_force
# out_1_8reff_exs_force
# out_1_8reff_exs_force
# out_1_8reff_exs_force
# out_2_8reff_ins
# out_2_8reff_ins
# out_2_8reff_ins
# out_2_8reff_ins
# out_2_8reff_ins
# out_2_8reff_ins
# out_2_8reff_exs
# out_2_8reff_exs
# out_2_8reff_exs
# out_2_8reff_exs
# out_2_8reff_exs
# out_2_8reff_exs
# out_2_8reff_gal
# out_2_8reff_gal
# out_2_8reff_gal
# out_2_8reff_gal
# out_2_8reff_gal
# out_2_8reff_gal
# out_2_8reff_ins_force
# out_2_8reff_ins_force
# out_2_8reff_ins_force
# out_2_8reff_ins_force
# out_2_8reff_ins_force
# out_2_8reff_ins_force
# out_2_8reff_exs_force
# out_2_8reff_exs_force
# out_2_8reff_exs_force
# out_2_8reff_exs_force
# out_2_8reff_exs_force
# out_2_8reff_exs_force
# out_3_8reff_ins
# out_3_8reff_ins
# out_3_8reff_ins
# out_3_8reff_ins
# out_3_8reff_ins
# out_3_8reff_ins
# out_3_8reff_exs
# out_3_8reff_exs
# out_3_8reff_exs
# out_3_8reff_exs
# out_3_8reff_exs
# out_3_8reff_exs
# out_3_8reff_gal
# out_3_8reff_gal
# out_3_8reff_gal
# out_3_8reff_gal
# out_3_8reff_gal
# out_3_8reff_gal
# out_3_8reff_ins_force
# out_3_8reff_ins_force
# out_3_8reff_ins_force
# out_3_8reff_ins_force
# out_3_8reff_ins_force
# out_3_8reff_ins_force
# out_3_8reff_exs_force
# out_3_8reff_exs_force
# out_3_8reff_exs_force
# out_3_8reff_exs_force
# out_3_8reff_exs_force
# out_3_8reff_exs_force
# out_4_8reff_ins
# out_4_8reff_ins
# out_4_8reff_ins
# out_4_8reff_ins
# out_4_8reff_ins
# out_4_8reff_ins
# /var/folders/x0/h_lnpc2s7tj88s2gg8lg03l80000gn/T/ipykernel_13244/4057521034.py:53: RuntimeWarning: divide by zero encountered in log10
#   mpeak=mpeakfind(np.log10(tab['aper_8reff_'+map_type]-tab['aper_'+str(i)+'reff_'+map_type]))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [14], in <cell line: 49>()
#      51 exec('name="out_'+str(i)+'_8reff_'+map_type+'"')
#      52 name_tab.append('out_'+str(i)+'_8reff_'+map_type)
# ---> 53 mpeak=mpeakfind(np.log10(tab['aper_8reff_'+map_type]-tab['aper_'+str(i)+'reff_'+map_type]))
#      54 mask=(tab['aper_8reff_'+map_type]-tab['aper_'+str(i)+'reff_'+map_type]>10**mpeak)
#      55 for j in range(len(numb_list)):
#
# Input In [7], in mpeakfind(tab, bin_num)
#       1 def mpeakfind(tab,bin_num=30):
# ----> 2     numb,bins=np.histogram(tab,bins=bin_num)
#       3     max_value=max(numb)
#       4     max_index=list(numb).index(max_value)
#
# File <__array_function__ internals>:180, in histogram(*args, **kwargs)
#
# File ~/miniconda3/envs/tardis/lib/python3.8/site-packages/numpy/lib/histograms.py:793, in histogram(a, bins, range, normed, weights, density)
#     681 r"""
#     682 Compute the histogram of a dataset.
#     683
#    (...)
#     789
#     790 """
#     791 a, weights = _ravel_and_check_weights(a, weights)
# --> 793 bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     795 # Histogram is an integer or a float array depending on the weights.
#     796 if weights is None:
#
# File ~/miniconda3/envs/tardis/lib/python3.8/site-packages/numpy/lib/histograms.py:426, in _get_bin_edges(a, bins, range, weights)
#     423     if n_equal_bins < 1:
#     424         raise ValueError('`bins` must be positive, when an integer')
# --> 426     first_edge, last_edge = _get_outer_edges(a, range)
#     428 elif np.ndim(bins) == 1:
#     429     bin_edges = np.asarray(bins)
#
# File ~/miniconda3/envs/tardis/lib/python3.8/site-packages/numpy/lib/histograms.py:323, in _get_outer_edges(a, range)
#     321     first_edge, last_edge = a.min(), a.max()
#     322     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# --> 323         raise ValueError(
#     324             "autodetected range of [{}, {}] is not finite".format(first_edge, last_edge))
#     326 # expand empty range to avoid divide by zero
#     327 if first_edge == last_edge:
#
# ValueError: autodetected range of [-inf, 11.432093830685202] is not finite

# %%
for i in sma_list0[:-2:]:
    for map_type in ('ins','exs','gal','ins_force','exs_force'):
        exec('name="out_'+str(i)+'_8reff_'+map_type+'"')
        name_tab.append('out_'+str(i)+'_8reff_'+map_type)
        mask0=(tab['aper_8reff_'+map_type]-tab['aper_'+str(i)+'reff_'+map_type])>0
        mpeak=mpeakfind(np.log10(tab[mask0]['aper_8reff_'+map_type]-tab[mask0]['aper_'+str(i)+'reff_'+map_type]))
        mask=(tab['aper_8reff_'+map_type]-tab['aper_'+str(i)+'reff_'+map_type]>10**mpeak)
        for j in range(len(numb_list)):
            mean,err=mocktopNreffscatter(tab[mask],name,numb_list[j])
            exec('tng300_'+str(numb_list[j])+'_scatter_mean.append(mean)')
            exec('tng300_'+str(numb_list[j])+'_scatter_err.append(err)')
# Out:
# out_1_8reff_ins
# out_1_8reff_ins
# out_1_8reff_ins
# out_1_8reff_ins
# out_1_8reff_ins
# out_1_8reff_ins
# out_1_8reff_exs
# out_1_8reff_exs
# out_1_8reff_exs
# out_1_8reff_exs
# out_1_8reff_exs
# out_1_8reff_exs
# out_1_8reff_gal
# out_1_8reff_gal
# out_1_8reff_gal
# out_1_8reff_gal
# out_1_8reff_gal
# out_1_8reff_gal
# out_1_8reff_ins_force
# out_1_8reff_ins_force
# out_1_8reff_ins_force
# out_1_8reff_ins_force
# out_1_8reff_ins_force
# out_1_8reff_ins_force
# out_1_8reff_exs_force
# out_1_8reff_exs_force
# out_1_8reff_exs_force
# out_1_8reff_exs_force
# out_1_8reff_exs_force
# out_1_8reff_exs_force
# out_2_8reff_ins
# out_2_8reff_ins
# out_2_8reff_ins
# out_2_8reff_ins
# out_2_8reff_ins
# out_2_8reff_ins
# out_2_8reff_exs
# out_2_8reff_exs
# out_2_8reff_exs
# out_2_8reff_exs
# out_2_8reff_exs
# out_2_8reff_exs
# out_2_8reff_gal
# out_2_8reff_gal
# out_2_8reff_gal
# out_2_8reff_gal
# out_2_8reff_gal
# out_2_8reff_gal
# out_2_8reff_ins_force
# out_2_8reff_ins_force
# out_2_8reff_ins_force
# out_2_8reff_ins_force
# out_2_8reff_ins_force
# out_2_8reff_ins_force
# out_2_8reff_exs_force
# out_2_8reff_exs_force
# out_2_8reff_exs_force
# out_2_8reff_exs_force
# out_2_8reff_exs_force
# out_2_8reff_exs_force
# out_3_8reff_ins
# out_3_8reff_ins
# out_3_8reff_ins
# out_3_8reff_ins
# out_3_8reff_ins
# out_3_8reff_ins
# out_3_8reff_exs
# out_3_8reff_exs
# out_3_8reff_exs
# out_3_8reff_exs
# out_3_8reff_exs
# out_3_8reff_exs
# out_3_8reff_gal
# out_3_8reff_gal
# out_3_8reff_gal
# out_3_8reff_gal
# out_3_8reff_gal
# out_3_8reff_gal
# out_3_8reff_ins_force
# out_3_8reff_ins_force
# out_3_8reff_ins_force
# out_3_8reff_ins_force
# out_3_8reff_ins_force
# out_3_8reff_ins_force
# out_3_8reff_exs_force
# out_3_8reff_exs_force
# out_3_8reff_exs_force
# out_3_8reff_exs_force
# out_3_8reff_exs_force
# out_3_8reff_exs_force
# out_4_8reff_ins
# out_4_8reff_ins
# out_4_8reff_ins
# out_4_8reff_ins
# out_4_8reff_ins
# out_4_8reff_ins
# out_4_8reff_exs
# out_4_8reff_exs
# out_4_8reff_exs
# out_4_8reff_exs
# out_4_8reff_exs
# out_4_8reff_exs
# out_4_8reff_gal
# out_4_8reff_gal
# out_4_8reff_gal
# out_4_8reff_gal
# out_4_8reff_gal
# out_4_8reff_gal
# out_4_8reff_ins_force
# out_4_8reff_ins_force
# out_4_8reff_ins_force
# out_4_8reff_ins_force
# out_4_8reff_ins_force
# out_4_8reff_ins_force
# out_4_8reff_exs_force
# out_4_8reff_exs_force
# out_4_8reff_exs_force
# out_4_8reff_exs_force
# out_4_8reff_exs_force
# out_4_8reff_exs_force
# out_5_8reff_ins
# out_5_8reff_ins
# out_5_8reff_ins
# out_5_8reff_ins
# out_5_8reff_ins
# out_5_8reff_ins
# out_5_8reff_exs
# out_5_8reff_exs
# out_5_8reff_exs
# out_5_8reff_exs
# out_5_8reff_exs
# out_5_8reff_exs
# out_5_8reff_gal
# out_5_8reff_gal
# out_5_8reff_gal
# out_5_8reff_gal
# out_5_8reff_gal
# out_5_8reff_gal
# out_5_8reff_ins_force
# out_5_8reff_ins_force
# out_5_8reff_ins_force
# out_5_8reff_ins_force
# out_5_8reff_ins_force
# out_5_8reff_ins_force
# out_5_8reff_exs_force
# out_5_8reff_exs_force
# out_5_8reff_exs_force
# out_5_8reff_exs_force
# out_5_8reff_exs_force
# out_5_8reff_exs_force

# %%
str0=','
str1=','
for i in range(len(numb_list)):
    str0=str0+'tng300_'+str(numb_list[i])+'_scatter_mean,'+'tng300_'+str(numb_list[i])+'_scatter_err,'
    str1=str1+'"tng300_'+str(numb_list[i])+'_scatter_mean",'+'"tng300_'+str(numb_list[i])+'_scatter_err",'

# %%
exec('topN_tab1=QTable([name_tab'+str0[:-1:]+'],names=("item"'+str1[:-1:]+'))')

# %%
numb_list=numb_list2
mask0=(tab0['catsh_primary']==True)&(tab0['proj']=='xy')&(tab0["mass_stellar_ins"]>1e10)&(tab0["mass_stellar_exs"]>10**10.5)
name_tab=[]
tab=tab0[mask0]
for i in range(len(numb_list)-1):
    exec('tng300_'+str(numb_list[i])+'_'+str(numb_list[i+1])+'_scatter_mean=[]')
    exec('tng300_'+str(numb_list[i])+'_'+str(numb_list[i+1])+'_scatter_err=[]')
for i in sma_list:
    for map_type in ('ins','exs','gal'):
        exec('name="aper_'+str(i)+'_'+map_type+'"')
        name_tab.append('aper_'+str(i)+'_'+map_type)
        mpeak=mpeakfind(np.log10(tab['aper_'+str(i)+'_'+map_type]))
        mask=(tab['aper_'+str(i)+'_'+map_type]>10**mpeak)
        for j in range(len(numb_list)-1):
            mean,err=mockmedNscatter(tab[mask],name,numb_list[j],numb_list[j+1])
            exec('tng300_'+str(numb_list[j])+'_'+str(numb_list[j+1])+'_scatter_mean.append(mean)')
            exec('tng300_'+str(numb_list[j])+'_'+str(numb_list[j+1])+'_scatter_err.append(err)')
for i in sma_list[:-2:]:
    for map_type in ('ins','exs','gal'):
        exec('name="out_'+str(i)+'_100_'+map_type+'"')
        name_tab.append('out_'+str(i)+'_100_'+map_type)
        mpeak=mpeakfind(np.log10(tab['aper_100_'+map_type]-tab['aper_'+str(i)+'_'+map_type]))
        mask=(tab['aper_100_'+map_type]-tab['aper_'+str(i)+'_'+map_type]>10**mpeak)
        for j in range(len(numb_list)-1):
            mean,err=mockmedNscatter(tab[mask],name,numb_list[j],numb_list[j+1])
            exec('tng300_'+str(numb_list[j])+'_'+str(numb_list[j+1])+'_scatter_mean.append(mean)')
            exec('tng300_'+str(numb_list[j])+'_'+str(numb_list[j+1])+'_scatter_err.append(err)')
for map_type in ('ins','exs','gal'):
    exec('name="mass_stellar_'+map_type+'"')
    name_tab.append('mass_stellar_'+map_type)
    mpeak=mpeakfind(np.log10(tab[name]))
    mask=(tab[name]>10**mpeak)
    for j in range(len(numb_list)-1):
        mean,err=mockmedNscatter(tab[mask],name,numb_list[j],numb_list[j+1])
        exec('tng300_'+str(numb_list[j])+'_'+str(numb_list[j+1])+'_scatter_mean.append(mean)')
        exec('tng300_'+str(numb_list[j])+'_'+str(numb_list[j+1])+'_scatter_err.append(err)')
mask1=(tab1['catsh_primary']==True)&(tab1['proj']=='xy')&(tab1["mass_stellar_ins"]>1e10)&(tab1["mass_stellar_exs"]>10**10.5)
tab=tab1[mask1]
for i in sma_list0:
    for map_type in ('ins','exs','gal','ins_force','exs_force'):
        exec('name="aper_'+str(i)+'reff_'+map_type+'"')
        name_tab.append('aper_'+str(i)+'reff_'+map_type)
        mpeak=mpeakfind(np.log10(tab['aper_'+str(i)+'reff_'+map_type]))
        mask=(tab['aper_'+str(i)+'reff_'+map_type]>10**mpeak)
        for j in range(len(numb_list)-1):
            mean,err=mockmedNreffscatter(tab[mask],name,numb_list[j],numb_list[j+1])
            exec('tng300_'+str(numb_list[j])+'_'+str(numb_list[j+1])+'_scatter_mean.append(mean)')
            exec('tng300_'+str(numb_list[j])+'_'+str(numb_list[j+1])+'_scatter_err.append(err)')
for i in sma_list0[:-2:]:
    for map_type in ('ins','exs','gal','ins_force','exs_force'):
        exec('name="out_'+str(i)+'_8reff_'+map_type+'"')
        name_tab.append('out_'+str(i)+'_8reff_'+map_type)
        mask0=(tab['aper_8reff_'+map_type]-tab['aper_'+str(i)+'reff_'+map_type])>0
        mpeak=mpeakfind(np.log10(tab[mask0]['aper_8reff_'+map_type]-tab[mask0]['aper_'+str(i)+'reff_'+map_type]))
        mask=(tab['aper_8reff_'+map_type]-tab['aper_'+str(i)+'reff_'+map_type]>10**mpeak)
        for j in range(len(numb_list)-1):
            mean,err=mockmedNreffscatter(tab[mask],name,numb_list[j],numb_list[j+1])
            exec('tng300_'+str(numb_list[j])+'_'+str(numb_list[j+1])+'_scatter_mean.append(mean)')
            exec('tng300_'+str(numb_list[j])+'_'+str(numb_list[j+1])+'_scatter_err.append(err)')
# Out:
# aper_30_ins
# aper_30_ins
# aper_30_ins
# aper_30_ins
# aper_30_exs
# aper_30_exs
# aper_30_exs
# aper_30_exs
# aper_30_gal
# aper_30_gal
# aper_30_gal
# aper_30_gal
# aper_50_ins
# aper_50_ins
# aper_50_ins
# aper_50_ins
# aper_50_exs
# aper_50_exs
# aper_50_exs
# aper_50_exs
# aper_50_gal
# aper_50_gal
# aper_50_gal
# aper_50_gal
# aper_75_ins
# aper_75_ins
# aper_75_ins
# aper_75_ins
# aper_75_exs
# aper_75_exs
# aper_75_exs
# aper_75_exs
# aper_75_gal
# aper_75_gal
# aper_75_gal
# aper_75_gal
# aper_100_ins
# aper_100_ins
# aper_100_ins
# aper_100_ins
# aper_100_exs
# aper_100_exs
# aper_100_exs
# aper_100_exs
# aper_100_gal
# aper_100_gal
# aper_100_gal
# aper_100_gal
# aper_150_ins
# aper_150_ins
# aper_150_ins
# aper_150_ins
# aper_150_exs
# aper_150_exs
# aper_150_exs
# aper_150_exs
# aper_150_gal
# aper_150_gal
# aper_150_gal
# aper_150_gal
# out_30_100_ins
# out_30_100_ins
# out_30_100_ins
# out_30_100_ins
# out_30_100_exs
# out_30_100_exs
# out_30_100_exs
# out_30_100_exs
# out_30_100_gal
# out_30_100_gal
# out_30_100_gal
# out_30_100_gal
# out_50_100_ins
# out_50_100_ins
# out_50_100_ins
# out_50_100_ins
# out_50_100_exs
# out_50_100_exs
# out_50_100_exs
# out_50_100_exs
# out_50_100_gal
# out_50_100_gal
# out_50_100_gal
# out_50_100_gal
# out_75_100_ins
# out_75_100_ins
# out_75_100_ins
# out_75_100_ins
# out_75_100_exs
# out_75_100_exs
# out_75_100_exs
# out_75_100_exs
# out_75_100_gal
# out_75_100_gal
# out_75_100_gal
# out_75_100_gal
# mass_stellar_ins
# mass_stellar_ins
# mass_stellar_ins
# mass_stellar_ins
# mass_stellar_exs
# mass_stellar_exs
# mass_stellar_exs
# mass_stellar_exs
# mass_stellar_gal
# mass_stellar_gal
# mass_stellar_gal
# mass_stellar_gal
# aper_1reff_ins
# aper_1reff_ins
# aper_1reff_ins
# aper_1reff_ins
# aper_1reff_exs
# aper_1reff_exs
# aper_1reff_exs
# aper_1reff_exs
# aper_1reff_gal
# aper_1reff_gal
# aper_1reff_gal
# aper_1reff_gal
# aper_1reff_ins_force
# aper_1reff_ins_force
# aper_1reff_ins_force
# aper_1reff_ins_force
# aper_1reff_exs_force
# aper_1reff_exs_force
# aper_1reff_exs_force
# aper_1reff_exs_force
# aper_2reff_ins
# aper_2reff_ins
# aper_2reff_ins
# aper_2reff_ins
# aper_2reff_exs
# aper_2reff_exs
# aper_2reff_exs
# aper_2reff_exs
# aper_2reff_gal
# aper_2reff_gal
# aper_2reff_gal
# aper_2reff_gal
# aper_2reff_ins_force
# aper_2reff_ins_force
# aper_2reff_ins_force
# aper_2reff_ins_force
# aper_2reff_exs_force
# aper_2reff_exs_force
# aper_2reff_exs_force
# aper_2reff_exs_force
# aper_3reff_ins
# aper_3reff_ins
# aper_3reff_ins
# aper_3reff_ins
# aper_3reff_exs
# aper_3reff_exs
# aper_3reff_exs
# aper_3reff_exs
# aper_3reff_gal
# aper_3reff_gal
# aper_3reff_gal
# aper_3reff_gal
# aper_3reff_ins_force
# aper_3reff_ins_force
# aper_3reff_ins_force
# aper_3reff_ins_force
# aper_3reff_exs_force
# aper_3reff_exs_force
# aper_3reff_exs_force
# aper_3reff_exs_force
# aper_4reff_ins
# aper_4reff_ins
# aper_4reff_ins
# aper_4reff_ins
# aper_4reff_exs
# aper_4reff_exs
# aper_4reff_exs
# aper_4reff_exs
# aper_4reff_gal
# aper_4reff_gal
# aper_4reff_gal
# aper_4reff_gal
# aper_4reff_ins_force
# aper_4reff_ins_force
# aper_4reff_ins_force
# aper_4reff_ins_force
# aper_4reff_exs_force
# aper_4reff_exs_force
# aper_4reff_exs_force
# aper_4reff_exs_force
# aper_5reff_ins
# aper_5reff_ins
# aper_5reff_ins
# aper_5reff_ins
# aper_5reff_exs
# aper_5reff_exs
# aper_5reff_exs
# aper_5reff_exs
# aper_5reff_gal
# aper_5reff_gal
# aper_5reff_gal
# aper_5reff_gal
# aper_5reff_ins_force
# aper_5reff_ins_force
# aper_5reff_ins_force
# aper_5reff_ins_force
# aper_5reff_exs_force
# aper_5reff_exs_force
# aper_5reff_exs_force
# aper_5reff_exs_force
# aper_8reff_ins
# aper_8reff_ins
# aper_8reff_ins
# aper_8reff_ins
# aper_8reff_exs
# aper_8reff_exs
# aper_8reff_exs
# aper_8reff_exs
# aper_8reff_gal
# aper_8reff_gal
# aper_8reff_gal
# aper_8reff_gal
# aper_8reff_ins_force
# aper_8reff_ins_force
# aper_8reff_ins_force
# aper_8reff_ins_force
# aper_8reff_exs_force
# aper_8reff_exs_force
# aper_8reff_exs_force
# aper_8reff_exs_force
# aper_10reff_ins
# aper_10reff_ins
# aper_10reff_ins
# aper_10reff_ins
# aper_10reff_exs
# aper_10reff_exs
# aper_10reff_exs
# aper_10reff_exs
# aper_10reff_gal
# aper_10reff_gal
# aper_10reff_gal
# aper_10reff_gal
# aper_10reff_ins_force
# aper_10reff_ins_force
# aper_10reff_ins_force
# aper_10reff_ins_force
# aper_10reff_exs_force
# aper_10reff_exs_force
# aper_10reff_exs_force
# aper_10reff_exs_force
# out_1_8reff_ins
# out_1_8reff_ins
# out_1_8reff_ins
# out_1_8reff_ins
# out_1_8reff_exs
# out_1_8reff_exs
# out_1_8reff_exs
# out_1_8reff_exs
# out_1_8reff_gal
# out_1_8reff_gal
# out_1_8reff_gal
# out_1_8reff_gal
# out_1_8reff_ins_force
# out_1_8reff_ins_force
# out_1_8reff_ins_force
# out_1_8reff_ins_force
# out_1_8reff_exs_force
# out_1_8reff_exs_force
# out_1_8reff_exs_force
# out_1_8reff_exs_force
# out_2_8reff_ins
# out_2_8reff_ins
# out_2_8reff_ins
# out_2_8reff_ins
# out_2_8reff_exs
# out_2_8reff_exs
# out_2_8reff_exs
# out_2_8reff_exs
# out_2_8reff_gal
# out_2_8reff_gal
# out_2_8reff_gal
# out_2_8reff_gal
# out_2_8reff_ins_force
# out_2_8reff_ins_force
# out_2_8reff_ins_force
# out_2_8reff_ins_force
# out_2_8reff_exs_force
# out_2_8reff_exs_force
# out_2_8reff_exs_force
# out_2_8reff_exs_force
# out_3_8reff_ins
# out_3_8reff_ins
# out_3_8reff_ins
# out_3_8reff_ins
# out_3_8reff_exs
# out_3_8reff_exs
# out_3_8reff_exs
# out_3_8reff_exs
# out_3_8reff_gal
# out_3_8reff_gal
# out_3_8reff_gal
# out_3_8reff_gal
# out_3_8reff_ins_force
# out_3_8reff_ins_force
# out_3_8reff_ins_force
# out_3_8reff_ins_force
# out_3_8reff_exs_force
# out_3_8reff_exs_force
# out_3_8reff_exs_force
# out_3_8reff_exs_force
# out_4_8reff_ins
# out_4_8reff_ins
# out_4_8reff_ins
# out_4_8reff_ins
# out_4_8reff_exs
# out_4_8reff_exs
# out_4_8reff_exs
# out_4_8reff_exs
# out_4_8reff_gal
# out_4_8reff_gal
# out_4_8reff_gal
# out_4_8reff_gal
# out_4_8reff_ins_force
# out_4_8reff_ins_force
# out_4_8reff_ins_force
# out_4_8reff_ins_force
# out_4_8reff_exs_force
# out_4_8reff_exs_force
# out_4_8reff_exs_force
# out_4_8reff_exs_force
# out_5_8reff_ins
# out_5_8reff_ins
# out_5_8reff_ins
# out_5_8reff_ins
# out_5_8reff_exs
# out_5_8reff_exs
# out_5_8reff_exs
# out_5_8reff_exs
# out_5_8reff_gal
# out_5_8reff_gal
# out_5_8reff_gal
# out_5_8reff_gal
# out_5_8reff_ins_force
# out_5_8reff_ins_force
# out_5_8reff_ins_force
# out_5_8reff_ins_force
# out_5_8reff_exs_force
# out_5_8reff_exs_force
# out_5_8reff_exs_force
# out_5_8reff_exs_force

# %%
str0=','
str1=','
for i in range(len(numb_list)-1):
    str0=str0+'tng300_'+str(numb_list[i])+'_'+str(numb_list[i+1])+'_scatter_mean,'+'tng300_'+str(numb_list[i])+'_'+str(numb_list[i+1])+'_scatter_err,'
    str1=str1+'"tng300_'+str(numb_list[i])+'_'+str(numb_list[i+1])+'_scatter_mean",'+'"tng300_'+str(numb_list[i])+'_'+str(numb_list[i+1])+'_scatter_err",'

# %%
exec('topN_tab2=QTable([name_tab'+str0[:-1:]+'],names=("item"'+str1[:-1:]+'))')

# %%
with open(data_dir+"galaxies_tng300_072_mock_topN_final.txt",'rb') as f: 
    topN_tab1=pickle.load(f)
with open(data_dir+"galaxies_tng300_072_mock_topN_final_2.txt",'rb') as f: 
    topN_tab2=pickle.load(f)

# %%
topN_tab2
# Out:
# <QTable length=87>
#          item         ... tng300_700_1200_scatter_err
#         str21         ...           float64
# --------------------- ... ---------------------------
#           aper_30_ins ...       0.0063225485318644204
#           aper_30_exs ...       0.0048762866673182515
#           aper_30_gal ...        0.005846668732830893
#           aper_50_ins ...         0.00642964667074922
#           aper_50_exs ...         0.00495174871791945
#           aper_50_gal ...       0.0052680841662618985
#                   ... ...                         ...
# out_4_8reff_ins_force ...        0.006340570525814494
# out_4_8reff_exs_force ...       0.0038900467201364477
#       out_5_8reff_ins ...        0.005991114069324375
#       out_5_8reff_exs ...        0.005898094428462396
#       out_5_8reff_gal ...        0.006899554591612198
# out_5_8reff_ins_force ...        0.005550457971997027
# out_5_8reff_exs_force ...        0.005968062206655782

# %%
numb_list=np.asarray([50,100,200,500,1000,1500])
numb_list2=np.asarray([800,400,200,100])
numblist=[r'$50$',r'$100$',r'$200$',r'$500$',r'$1000$',r'$1500$']
color_list=['blue','orange','red','darkgreen','purple']
numblist2=[r'$[50,180]$',r'$[180,350]$',r'$[350,700]$',r'$[700,1200]$']
namelist=['aper_30_gal','aper_100_gal','out_50_100_gal','aper_8reff_gal','out_4_8reff_gal']
labellist=[r'$M_{\star,30{\rm\ kpc}}$',r'$M_{\star,100{\rm\ kpc}}$',r'$M_{\star,[50,100]{\rm\ kpc}}$',r'$M_{\star,8\ R_{\rm e}}$',r'$M_{\star,[4,8]\ R_{\rm e}}$']
markerlist=['o','s','p','P','H','X','D','v','*','8','>']
sizelist=np.asarray([10,9,14,12,12,9,9,9,9,9,9])*1.5
fig=plt.figure(figsize=(24, 8))
gs = fig.add_gridspec(1,2, hspace=0, wspace=0.1)
(ax1,ax2)= gs.subplots(sharex='col')
ax1.axvspan(1450,2100,color='darkgrey',alpha=0.2)
for i in range(len(namelist)):
    col=color_list[i]
    ax1.errorbar(numb_list*2**(i/10),np.asarray(list(topN_tab1[topN_tab1['item']==namelist[i]][0])[1::2]),yerr=np.asarray(list(topN_tab1[topN_tab1['item']==namelist[i]][0])[2::2]),alpha=1,fmt=markerlist[i],markersize=sizelist[i],
                 capsize=6, capthick=1.5,elinewidth=1,c=col,mec='white',label=labellist[i])
    ax2.errorbar(numb_list2*2**(i/15),np.asarray(list(topN_tab2[topN_tab2['item']==namelist[i]][0])[1::2]),yerr=np.asarray(list(topN_tab2[topN_tab2['item']==namelist[i]][0])[2::2]),alpha=1,fmt=markerlist[i],markersize=sizelist[i],
                 capsize=6, capthick=1.5,elinewidth=1,c=col,mec='white',label=labellist[i])
name='mass_stellar_gal'
err=np.asarray(list(topN_tab1[topN_tab1['item']==name][0])[2::2])
ax1.fill_between(numb_list*2**(1.5/20),np.asarray(list(topN_tab1[topN_tab1['item']==name][0])[1::2])+err,np.asarray(list(topN_tab1[topN_tab1['item']==name][0])[1::2])-err,alpha=0.2,color='lightseagreen',label=r'$M_{\rm exs}$',edgecolor=None)
err=np.asarray(list(topN_tab2[topN_tab2['item']==name][0])[2::2])
ax2.fill_between(numb_list2*2**(1.5/20),np.asarray(list(topN_tab2[topN_tab2['item']==name][0])[1::2])+err,np.asarray(list(topN_tab2[topN_tab2['item']==name][0])[1::2])-err,alpha=0.2,color='lightseagreen',label=r'$M_{\rm exs}$',edgecolor=None)
ax1.set_xlabel(r'\rm Top N',fontsize=35)
ax2.set_xlabel(r'\rm Top N Bins',fontsize=35)
ax1.set_ylabel(r'$\sigma_{\log{M_{\rm halo}}}$',fontsize=35)

ax1.set_xlim(40,2100)
ax1.invert_xaxis()
ax1.set_xscale('log')
ax2.set_xscale('log')
ax1.set_xticks(numb_list,numblist)
ax2.set_xticks(numb_list2,numblist2)

ax1.legend(fontsize=28,ncol=6,bbox_to_anchor =(2.12, 1.2))
ax1.arrow(500,0.36,-400,0,head_length=10,width=0.001)
ax1.text(0.85,0.92,r'$M_\star$',transform=ax1.transAxes, size=28)
ax2.text(0.55,0.92,r'$M_\star$',transform=ax2.transAxes, size=28)
ax2.arrow(100,0.26,200,0,head_length=20,width=0.0008)
plt.savefig(fig_dir+'Fig5.png',dpi=200)
